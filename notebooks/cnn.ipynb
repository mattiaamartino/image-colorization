# %% [markdown]
# # CNN Model

# %% [markdown]
# This notebook contains the construction and the evaluations of CNN models for colorization purposes.

# %%
import torch
from torch.utils.data import DataLoader, random_split
import torchvision.transforms as transforms
import torch.nn as nn
from tqdm import tqdm
import torch.optim as optim
from utils.dataset import CocoDataset
from utils.plots import plot_l, reconstruct_lab, plot_model_pred, plot_losses
from utils.models import CNN, save_model, load_model
from utils.metrics import evaluate_model
from utils.training import train_cnn, load_losses
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ## Data import

# %%
height, width = 256, 256

transform = transforms.Compose([
    transforms.Resize((height, width)),
    transforms.ToTensor(), # tensorization brings image in range [0,1] and space CxHxW
])

# %%
path_sandro = "coco/images/train2014"
path_diego = "C:/Users/diego/coco/images/train2014/train2014"
path_vm = "/home/default/coco/train/"
dataset = CocoDataset(root=path_vm, transform=transform)
# Out:
# Found 82783 images.

# %% [markdown]
# ## Data preparation

# %% [markdown]
# We split our dataset in train and test data.

# %%
torch.manual_seed(42)
test_size = int(0.2 * len(dataset))
train_size = len(dataset) - test_size
train, test = random_split(dataset, [train_size, test_size])
train_loader = DataLoader(train, batch_size=64, shuffle=True)
test_loader = DataLoader(test, batch_size=64, shuffle=False)
train_size = 5000
small_train, _ = random_split(train, [train_size, len(train) - train_size])
small_train_loader = DataLoader(small_train, batch_size=64, shuffle=True)
test_size = 1000
small_test, _ = random_split(test, [test_size, len(test) - test_size])
small_test_loader = DataLoader(small_test, batch_size=64, shuffle=False)

# %% [markdown]
# ## CNN Model

# %%
NUM_EPOCHS = 30

# %% [markdown]
# ### MSE Loss

# %%
torch.manual_seed(42)
model = CNN(height, width).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-4, betas=(0.9, 0.999))
criterion1 = nn.MSELoss()

# %%
torch.manual_seed(42)
train_losses, test_losses = train_cnn(NUM_EPOCHS, model, criterion1, optimizer, small_train_loader, small_test_loader, device,
                                      save_losses=True, save_checkpoints=True, file_name="cnn")
# output qui sotto è vecchio
# Out:
# Checkpoints will not be saved. Epochs must be greater than or equal to 10 for saving checkpoints.
# Epoch 1/2: 100%|██████████| 79/79 [01:52<00:00,  1.43s/it]
# Testing: 100%|██████████| 16/16 [00:22<00:00,  1.40s/it]
# Epoch 1, Train Loss: 0.005166402169137816, Validation Loss: 0.0040736095252214
# Epoch 2/2: 100%|██████████| 79/79 [01:49<00:00,  1.39s/it]
# Testing: 100%|██████████| 16/16 [00:21<00:00,  1.35s/it]
# Epoch 2, Train Loss: 0.0040369933866011565, Validation Loss: 0.003551928384695202
# Losses saved to losses/cnn.txt
# Finished Training

# %%
plot_losses(train_losses, test_losses)

# %%
save_model(model, "CNN_MSELoss")
# Out:
# Model saved to models/CNN_MSELoss.pth successfully!

# %%
loaded_model1 = load_model(CNN(height, width), "models/CNN_MSELoss.pth").to(device)
# Out:
# CNN model loaded successfully!

# %%
plot_l(dataset[7653][1])
plot_model_pred(dataset[7653][1], loaded_model1, device)

# %%
torch.manual_seed(42)
avg_mse, avg_psnr, avg_ssim, fid = evaluate_model(loaded_model1, small_test_loader, device)
print(f"Average MSE: {avg_mse:.4f}")
print(f"Average PSNR: {avg_psnr:.4f}")
print(f"Average SSIM: {avg_ssim:.4f}")
print(f"FID: {fid:.4f}")
# Out:
# Average MSE: 0.0035
# Average PSNR: 49.1729
# Average SSIM: 0.7755
# FID: 28.4676

# %%
torch.manual_seed(42)
train_losses_test, test_losses_test = train_cnn(2, model, criterion1, optimizer, small_train_loader, small_test_loader, device,
                                      save_losses=True, save_checkpoints=True, file_name="cnn")
# Out:
# Checkpoints will not be saved. Epochs must be greater than or equal to 10 for saving checkpoints.
# Epoch 1/2: 100%|██████████| 79/79 [01:29<00:00,  1.14s/it]
# Testing: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# Epoch 1, Train Loss: 0.2504752629165408, Validation Loss: 0.18608183693140745
# Epoch 2/2: 100%|██████████| 79/79 [01:28<00:00,  1.12s/it]
# Testing: 100%|██████████| 16/16 [00:17<00:00,  1.09s/it]
# Epoch 2, Train Loss: 0.1182830351157279, Validation Loss: 0.06155079463496804
# Losses saved to losses\cnn.txt
# Finished Training

# %%
plot_losses(train_losses_test, test_losses_test)

# %%
loaded_train, loaded_test = load_losses("losses/cnn.txt")

# %%
plot_losses(loaded_train, loaded_test)

# %% [markdown]
# ### L1 Loss

# %%
torch.manual_seed(42)
model = CNN(height, width).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-4, betas=(0.9, 0.999))
criterion2 = nn.L1Loss()

# %%
torch.manual_seed(42)
train_losses, test_losses = train_cnn(NUM_EPOCHS, model, criterion2, optimizer, small_train_loader, small_test_loader, device)

# %%
# torch.manual_seed(42)
# train_losses = []
# test_losses = []

# for epoch in range(NUM_EPOCHS):
#     running_loss = 0.0
#     test_loss = 0.0

#     # Training loop
#     model.train()
#     for _, l_channels, _, _, ab_channels in tqdm(small_train_loader, desc=f'Epoch {epoch + 1}/{NUM_EPOCHS}', leave=True):
#         l_channels, ab_channels = l_channels.to(device), ab_channels.to(device)

#         optimizer.zero_grad()
#         outputs = model(l_channels)
#         loss = criterion2(outputs, ab_channels)
#         loss.backward()
#         optimizer.step()

#         running_loss += loss.item()

#     # scheduler.step()  # Update the scheduler
#     train_losses.append(running_loss / len(train_loader))

#     # Testing loop
#     model.eval()
#     with torch.no_grad():
#         for _, l_channels, _, _, ab_channels in tqdm(small_test_loader, desc='Testing', leave=True):
#             l_channels, ab_channels = l_channels.to(device), ab_channels.to(device)
#             outputs = model(l_channels)
#             loss = criterion2(outputs, ab_channels)
#             test_loss += loss.item()

#     test_losses.append(test_loss / len(test_loader))

#     # Print training and validation losses
#     print(f"Epoch {epoch + 1}, Train Loss: {train_losses[-1]}, Validation Loss: {test_losses[-1]}")

# print('Finished Training')
# Out:
# Epoch 1/15: 100%|██████████| 79/79 [00:40<00:00,  1.97it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.03it/s]
# Epoch 1, Train Loss: 0.010877818005960344, Validation Loss: 0.0028675440626945276
# Epoch 2/15: 100%|██████████| 79/79 [00:39<00:00,  1.98it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  2.89it/s]
# Epoch 2, Train Loss: 0.0031171747703771084, Validation Loss: 0.002579914902167891
# Epoch 3/15: 100%|██████████| 79/79 [00:38<00:00,  2.04it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  2.95it/s]
# Epoch 3, Train Loss: 0.002982604723189764, Validation Loss: 0.002515477203839534
# Epoch 4/15: 100%|██████████| 79/79 [00:38<00:00,  2.07it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.12it/s]
# Epoch 4, Train Loss: 0.0029455114713901483, Validation Loss: 0.0025518674072611746
# Epoch 5/15: 100%|██████████| 79/79 [00:38<00:00,  2.05it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.13it/s]
# Epoch 5, Train Loss: 0.002943876090545009, Validation Loss: 0.002615086777444972
# Epoch 6/15: 100%|██████████| 79/79 [00:38<00:00,  2.07it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.12it/s]
# Epoch 6, Train Loss: 0.0029147215943405593, Validation Loss: 0.002476086012990318
# Epoch 7/15: 100%|██████████| 79/79 [00:38<00:00,  2.06it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.14it/s]
# Epoch 7, Train Loss: 0.0028924064377799704, Validation Loss: 0.00241786939124343
# Epoch 8/15: 100%|██████████| 79/79 [00:38<00:00,  2.07it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.13it/s]
# Epoch 8, Train Loss: 0.002905570834443189, Validation Loss: 0.0024565720218719203
# Epoch 9/15: 100%|██████████| 79/79 [00:38<00:00,  2.07it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.10it/s]
# Epoch 9, Train Loss: 0.0028750261822760395, Validation Loss: 0.0024101923446397523
# Epoch 10/15: 100%|██████████| 79/79 [00:38<00:00,  2.07it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.15it/s]
# Epoch 10, Train Loss: 0.002876082010531195, Validation Loss: 0.0024381203569730737
# Epoch 11/15: 100%|██████████| 79/79 [00:38<00:00,  2.07it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.14it/s]
# Epoch 11, Train Loss: 0.002874705728125457, Validation Loss: 0.002368933014197699
# Epoch 12/15: 100%|██████████| 79/79 [00:38<00:00,  2.07it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.12it/s]
# Epoch 12, Train Loss: 0.0028611226862179486, Validation Loss: 0.0023850915543591196
# Epoch 13/15: 100%|██████████| 79/79 [00:38<00:00,  2.05it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.10it/s]
# Epoch 13, Train Loss: 0.0028361484912282605, Validation Loss: 0.0024152678441126834
# Epoch 14/15: 100%|██████████| 79/79 [00:38<00:00,  2.06it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.14it/s]
# Epoch 14, Train Loss: 0.0028430810711090114, Validation Loss: 0.0023736026152450605
# Epoch 15/15: 100%|██████████| 79/79 [00:38<00:00,  2.06it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.13it/s]
# Epoch 15, Train Loss: 0.00283956340185686, Validation Loss: 0.00241447172512419
# Finished Training

# %%
# plt.figure(figsize=(10, 6))
# plt.plot(train_losses, label='train')
# plt.plot(test_losses, label='test')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.grid(linestyle = "--")
# plt.legend()
# plt.show()
plot_losses(train_losses, test_losses)

# %%
input = dataset[7653][1].to(device).unsqueeze(0)
ab = model(input).squeeze(0)
reconstruct_lab(dataset[7653][1].to(device).detach().cpu(), ab.detach().cpu())

# %%
save_model(model, "CNN_L1Loss")
# Out:
# Model saved to models\CNN_L1Loss.pth successfully!

# %%
loaded_model2 = load_model(CNN(height, width), "models/CNN_L1Loss.pth").to(device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 loaded_model2 = load_model(CNN(height, width), "models/CNN_L1Loss.pth").to(device)
#
# File c:\Users\sandr\Desktop\ML\project\image-colorization\utils\models.py:178, in load_model(model, model_path)
#     167 def load_model(model: torch.nn.Module, model_path: str):
#     168    """
#     169    Load a PyTorch model from a file.
#     170
#    (...)
#     176        torch.nn.Module: The model object with the loaded weights.
#     177    """
# --> 178    model.load_state_dict(torch.load(model_path))
#     179    print(f"{model._get_name()} model loaded successfully!")
#     180    return model
#
# File c:\Users\sandr\anaconda3\envs\colorization\Lib\site-packages\torch\nn\modules\module.py:2153, in Module.load_state_dict(self, state_dict, strict, assign)
#    2148         error_msgs.insert(
#    2149             0, 'Missing key(s) in state_dict: {}. '.format(
#    2150                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2152 if len(error_msgs) > 0:
# -> 2153     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2154                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2155 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for CNN:
# 	Missing key(s) in state_dict: "conv.0.weight", "conv.0.bias", "conv.1.weight", "conv.1.bias", "conv.1.running_mean", "conv.1.running_var", "conv.3.weight", "conv.3.bias", "conv.4.weight", "conv.4.bias", "conv.4.running_mean", "conv.4.running_var", "conv.6.weight", "conv.6.bias", "conv.7.weight", "conv.7.bias", "conv.7.running_mean", "conv.7.running_var", "conv.9.weight", "conv.9.bias", "conv.10.weight", "conv.10.bias", "conv.10.running_mean", "conv.10.running_var", "conv.12.weight", "conv.12.bias", "conv.13.weight", "conv.13.bias", "conv.13.running_mean", "conv.13.running_var", "conv.15.weight", "conv.15.bias", "conv.17.weight", "conv.17.bias", "conv.17.running_mean", "conv.17.running_var", "conv.18.weight", "conv.18.bias", "conv.19.weight", "conv.19.bias", "conv.19.running_mean", "conv.19.running_var", "conv.21.weight", "conv.21.bias", "conv.22.weight", "conv.22.bias", "conv.22.running_mean", "conv.22.running_var", "conv.24.weight", "conv.24.bias", "conv.25.weight", "conv.25.bias", "conv.25.running_mean", "conv.25.running_var", "fc1.weight", "fc1.bias", "fc2.weight", "fc2.bias".
# 	Unexpected key(s) in state_dict: "features.0.weight", "features.0.bias", "features.2.weight", "features.2.bias", "features.2.running_mean", "features.2.running_var", "features.2.num_batches_tracked", "features.3.weight", "features.3.bias", "features.5.weight", "features.5.bias", "features.5.running_mean", "features.5.running_var", "features.5.num_batches_tracked", "features.6.weight", "features.6.bias", "features.8.weight", "features.8.bias", "features.8.running_mean", "features.8.running_var", "features.8.num_batches_tracked", "features.9.weight", "features.9.bias", "features.11.weight", "features.11.bias", "features.11.running_mean", "features.11.running_var", "features.11.num_batches_tracked", "features.12.weight", "features.12.bias", "features.14.weight", "features.14.bias", "features.14.running_mean", "features.14.running_var", "features.14.num_batches_tracked", "features.15.weight", "features.15.bias", "features.17.weight", "features.17.bias", "features.17.running_mean", "features.17.running_var", "features.17.num_batches_tracked", "features.18.weight", "features.18.bias", "features.20.weight", "features.20.bias", "features.20.running_mean", "features.20.running_var", "features.20.num_batches_tracked", "features.21.weight", "features.21.bias", "features.23.weight", "features.23.bias", "features.23.running_mean", "features.23.running_var", "features.23.num_batches_tracked", "features.24.weight", "features.24.bias", "features.26.weight", "features.26.bias", "features.26.running_mean", "features.26.running_var", "features.26.num_batches_tracked", "fc.weight", "fc.bias".

# %%
plot_l(dataset[76][1])
plot_model_pred(dataset[76][1], loaded_model2, device)

# %%
torch.manual_seed(42)
avg_mse, avg_psnr, avg_ssim, fid = evaluate_model(loaded_model2, small_test_loader, device)
print(f"Average MSE: {avg_mse:.4f}")
print(f"Average PSNR: {avg_psnr:.4f}")
print(f"Average SSIM: {avg_ssim:.4f}")
print(f"FID: {fid:.4f}")
# Out:
# Average MSE: 0.0033
# Average PSNR: 49.6637

# %% [markdown]
# ### Smooth L1 loss

# %%
torch.manual_seed(42)
model = CNN(height, width).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-4, betas=(0.9, 0.999))
criterion3 = nn.SmoothL1Loss()

# %%
torch.manual_seed(42)
train_losses, test_losses = train_cnn(NUM_EPOCHS, model, criterion3, optimizer, small_train_loader, small_test_loader, device)

# %%
# torch.manual_seed(42)
# train_losses = []
# test_losses = []

# for epoch in range(NUM_EPOCHS):
#     running_loss = 0.0
#     test_loss = 0.0

#     # Training loop
#     model.train()
#     for _, l_channels, _, _, ab_channels in tqdm(small_train_loader, desc=f'Epoch {epoch + 1}/{NUM_EPOCHS}', leave=True):
#         l_channels, ab_channels = l_channels.to(device), ab_channels.to(device)

#         optimizer.zero_grad()
#         outputs = model(l_channels)
#         loss = criterion3(outputs, ab_channels)
#         loss.backward()
#         optimizer.step()

#         running_loss += loss.item()

#     # scheduler.step()  # Update the scheduler
#     train_losses.append(running_loss / len(train_loader))

#     # Testing loop
#     model.eval()
#     with torch.no_grad():
#         for _, l_channels, _, _, ab_channels in tqdm(small_test_loader, desc='Testing', leave=True):
#             l_channels, ab_channels = l_channels.to(device), ab_channels.to(device)
#             outputs = model(l_channels)
#             loss = criterion3(outputs, ab_channels)
#             test_loss += loss.item()

#     test_losses.append(test_loss / len(test_loader))

#     # Print training and validation losses
#     print(f"Epoch {epoch + 1}, Train Loss: {train_losses[-1]}, Validation Loss: {test_losses[-1]}")

# print('Finished Training')
# Out:
# Epoch 1/15: 100%|██████████| 79/79 [00:38<00:00,  2.07it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.11it/s]
# Epoch 1, Train Loss: 0.002830648135083417, Validation Loss: 0.0001388896071499494
# Epoch 2/15: 100%|██████████| 79/79 [00:38<00:00,  2.07it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.15it/s]
# Epoch 2, Train Loss: 0.0001483574387019023, Validation Loss: 0.00011229651492865734
# Epoch 3/15: 100%|██████████| 79/79 [00:38<00:00,  2.07it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.12it/s]
# Epoch 3, Train Loss: 0.00013277501391993773, Validation Loss: 0.00010430103691086231
# Epoch 4/15: 100%|██████████| 79/79 [00:38<00:00,  2.06it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.11it/s]
# Epoch 4, Train Loss: 0.00012539389828930875, Validation Loss: 0.00010300368838314269
# Epoch 5/15: 100%|██████████| 79/79 [00:37<00:00,  2.08it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.18it/s]
# Epoch 5, Train Loss: 0.0001240088522281264, Validation Loss: 0.000105739789151921
# Epoch 6/15: 100%|██████████| 79/79 [00:38<00:00,  2.08it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.08it/s]
# Epoch 6, Train Loss: 0.0001221459370178445, Validation Loss: 0.00010420696209382596
# Epoch 7/15: 100%|██████████| 79/79 [00:38<00:00,  2.06it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.10it/s]
# Epoch 7, Train Loss: 0.00012260266716911453, Validation Loss: 0.00010123214474070141
# Epoch 8/15: 100%|██████████| 79/79 [00:38<00:00,  2.07it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.12it/s]
# Epoch 8, Train Loss: 0.00012201366952849903, Validation Loss: 0.00010319653193692903
# Epoch 9/15: 100%|██████████| 79/79 [00:38<00:00,  2.06it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.15it/s]
# Epoch 9, Train Loss: 0.00012050736346844458, Validation Loss: 9.871723578027432e-05
# Epoch 10/15: 100%|██████████| 79/79 [00:38<00:00,  2.07it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.13it/s]
# Epoch 10, Train Loss: 0.00011873860474549918, Validation Loss: 0.00010221156841827175
# Epoch 11/15: 100%|██████████| 79/79 [00:38<00:00,  2.05it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.01it/s]
# Epoch 11, Train Loss: 0.00011936200901883956, Validation Loss: 9.948101558122051e-05
# Epoch 12/15: 100%|██████████| 79/79 [00:38<00:00,  2.05it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.10it/s]
# Epoch 12, Train Loss: 0.000119139580393507, Validation Loss: 9.758844180571987e-05
# Epoch 13/15: 100%|██████████| 79/79 [00:38<00:00,  2.06it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.14it/s]
# Epoch 13, Train Loss: 0.00011762718294391741, Validation Loss: 9.807834444876803e-05
# Epoch 14/15: 100%|██████████| 79/79 [00:38<00:00,  2.07it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.15it/s]
# Epoch 14, Train Loss: 0.00011730479517420709, Validation Loss: 0.00010589170395522504
# Epoch 15/15: 100%|██████████| 79/79 [00:38<00:00,  2.07it/s]
# Testing: 100%|██████████| 16/16 [00:05<00:00,  3.15it/s]
# Epoch 15, Train Loss: 0.00011730464647753515, Validation Loss: 9.980120985592539e-05
# Finished Training

# %%
# plt.figure(figsize=(10, 6))
# plt.plot(train_losses, label='train')
# plt.plot(test_losses, label='test')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.grid(linestyle = "--")
# plt.legend()
# plt.show()
plot_losses(train_losses, test_losses)

# %%
save_model(model, "CNN_SmoothL1")
# Out:
# Model saved to models\CNN_SmoothL1.pth successfully!

# %%
loaded_model3 = load_model(CNN(height, width), "models/CNN_SmoothL1.pth").to(device)
# Out:
# CNN model loaded successfully!

# %%
plot_l(dataset[7653][1])
plot_model_pred(dataset[7653][1], loaded_model3, device)

# %%
torch.manual_seed(42)
avg_mse, avg_psnr, avg_ssim, fid = evaluate_model(loaded_model3, small_test_loader, device)
print(f"Average MSE: {avg_mse:.4f}")
print(f"Average PSNR: {avg_psnr:.4f}")
print(f"Average SSIM: {avg_ssim:.4f}")
print(f"FID: {fid:.4f}")
# Out:
# Average MSE: 0.0032
# Average PSNR: 49.8480
